# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.metrics import r2_score

# %%
data=pd.read_csv("/content/advertising.csv")
data.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.shape
# Out:
# (200, 4)

# %%
x=data.drop(['Sales'], axis=1)
y=data['Sales']
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
x.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %% [markdown]
# Linear Regression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=linear.predict(x_test)
print(predictions)
# Out:
# [16.95725681 11.05069702 17.05979624 16.32472906 20.47894867 20.79672666
#  15.90331092 24.80009628  8.21902522 20.37030193  9.40463412  5.51525451
#   9.51178386 18.83572517 17.14389     8.23916972 11.7874545  14.75448935
#  10.74516214 17.34279573 12.54545674  6.26719639 20.07334344  7.95889133
#   9.93903883 12.54939999 22.98934615 21.96735696 19.24889135 16.68715929
#  12.2597583  10.36882679 15.8066941  15.5173367  15.25895497  7.58408049
#  20.62253298 19.90729466 12.04177026  9.85833802]

# %%
print(r2_score(y_test, predictions))
# Out:
# 0.9151853138556797

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVR
svr=SVR()

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred_svr=svr.predict(x_test)
print(pred_svr)
# Out:
# [17.38370384 10.04413377 17.37902888 16.12162933 19.68187074 19.2417979
#  16.6957696  21.54034146  8.30162557 19.58862119  8.60057172  7.83959711
#  10.10595121 18.91105166 16.95238298  8.06464455 11.70170844 15.75772892
#  11.65082827 17.40765984 14.02725457  7.79987448 19.89770655  9.20837068
#   9.63799026 12.93348402 21.35992613 20.56103026 19.27090136 17.23439742
#  13.1142242  10.75840879 16.42055334 15.82804918 16.12807005  8.07108631
#  20.1987549  19.21815763 12.93867204  9.54855945]

# %%
print(r2_score(y_test, pred_svr))
# Out:
# 0.8834421234332487

# %%
ax=data.plot.scatter(x='TV', y='Sales', figsize=(8,6), color='PINK')
ax.set_xlabel('Cost for TV Advertisement')
plt.show()
